# %% [markdown]
# <a href="https://colab.research.google.com/github/iupui-soic/pybootcamp/blob/main/sigandhi%20Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/patients.csv.gz')
df.head()
# Out:
#    subject_id gender  anchor_age  anchor_year anchor_year_group         dod
# 0    10000032      F          52         2180       2014 - 2016  2180-09-09
# 1    10000048      F          23         2126       2008 - 2010         NaN
# 2    10000068      F          19         2160       2008 - 2010         NaN
# 3    10000084      M          72         2160       2017 - 2019  2161-02-13
# 4    10000102      F          27         2136       2008 - 2010         NaN

# %%
df.count()
# Out:
# subject_id           299777
# gender               299777
# anchor_age           299777
# anchor_year          299777
# anchor_year_group    299777
# dod                   29088
# dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# F    158550
# M    141227
# Name: gender, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
Gender = ['M', 'F']
Number= [158550, 141227]

plt.bar(Gender, Number)

plt.show()

# %%
plt.hist(df['anchor_age'])
# Out:
# (array([55462., 35872., 27628., 29625., 30727., 31342., 31959., 21653.,
#         17640., 17869.]),
#  array([18. , 25.3, 32.6, 39.9, 47.2, 54.5, 61.8, 69.1, 76.4, 83.7, 91. ]),
#  <a list of 10 Patch objects>)

# %%
df.isnull()
# Out:
#         subject_id  gender  anchor_age  anchor_year  anchor_year_group    dod
# 0            False   False       False        False              False  False
# 1            False   False       False        False              False   True
# 2            False   False       False        False              False   True
# 3            False   False       False        False              False  False
# 4            False   False       False        False              False   True
# ...            ...     ...         ...          ...                ...    ...
# 299772       False   False       False        False              False   True
# 299773       False   False       False        False              False   True
# 299774       False   False       False        False              False  False
# 299775       False   False       False        False              False   True
# 299776       False   False       False        False              False   True
#
# [299777 rows x 6 columns]

# %%
df= df.fillna(0)
df
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000068      F          19         2160       2008 - 2010
# 3         10000084      M          72         2160       2017 - 2019
# 4         10000102      F          27         2136       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299772    19999828      F          46         2147       2017 - 2019
# 299773    19999829      F          28         2186       2008 - 2010
# 299774    19999840      M          58         2164       2008 - 2010
# 299775    19999914      F          49         2158       2017 - 2019
# 299776    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1                0
# 2                0
# 3       2161-02-13
# 4                0
# ...            ...
# 299772           0
# 299773           0
# 299774  2164-09-17
# 299775           0
# 299776           0
#
# [299777 rows x 6 columns]
